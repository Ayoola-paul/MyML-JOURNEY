# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("eda_practice_dataset.csv")
df.head()
# Out:
#   CustomerID  Country  Gender   Age   Salary Purchased     Category  Value  \
# 0       C001   France  Female  44.0  72000.0        No  Electronics    220
# 1       C002    Spain    Male  27.0  48000.0       Yes    Groceries     85
# 2       C003  Germany  Female  30.0  54000.0        No  Electronics    160
# 3       C004    Spain     NaN  38.0  61000.0        No      Fashion    140
# 4       C005  Germany    Male  40.0      NaN       Yes    Groceries     95
#
#   Region  Sales  Feature        Date
# 0   West   1200     15.2  2025-01-03
# 1  South    540     11.4  2025-01-04
# 2  North    800     12.1  2025-01-05
# 3  South    670     14.8  2025-01-06
# 4  North    450     13.0  2025-01-07

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  35 non-null     str
#  1   Country     35 non-null     str
#  2   Gender      34 non-null     str
#  3   Age         34 non-null     float64
#  4   Salary      34 non-null     float64
#  5   Purchased   35 non-null     str
#  6   Category    35 non-null     str
#  7   Value       35 non-null     int64
#  8   Region      35 non-null     str
#  9   Sales       35 non-null     int64
#  10  Feature     35 non-null     float64
#  11  Date        34 non-null     str
# dtypes: float64(3), int64(2), str(7)
# memory usage: 3.4 KB

# %%
df.tail()
# Out:
#    CustomerID  Country  Gender   Age    Salary Purchased     Category  Value  \
# 30       C031   France  Female  48.0   79000.0       Yes  Electronics    260
# 31       C032  Nigeria    Male  60.0  150000.0       Yes  Electronics    500
# 32       C033    Spain  Female  22.0   35000.0        No    Groceries     60
# 33       C034  Germany  Female  43.0   73000.0       Yes  Electronics    230
# 34       C013    Kenya  Female  41.0   62000.0        No      Fashion    150
#
#    Region  Sales  Feature        Date
# 30   West   1500     16.1  2025-02-02
# 31   West   4200     45.0  2025-02-03
# 32  South    300      9.8         NaN
# 33  North   1250     15.7  2025-01-23
# 34   East    740     13.9  2025-01-15

# %%
df.shape
# Out:
# (35, 12)

# %%
df.columns
# Out:
# Index(['CustomerID', 'Country', 'Gender', 'Age', 'Salary', 'Purchased',
#        'Category', 'Value', 'Region', 'Sales', 'Feature', 'Date'],
#       dtype='str')

# %%
df.describe()
# Out:
#              Age         Salary       Value        Sales    Feature
# count  34.000000      34.000000   35.000000    35.000000  35.000000
# mean   38.794118   65352.941176  173.600000   958.285714  14.731429
# std     8.899368   20013.453586   83.826221   671.580601   5.675788
# min    22.000000   35000.000000   60.000000   300.000000   9.800000
# 25%    31.250000   52250.000000  112.500000   585.000000  12.400000
# 50%    38.500000   62000.000000  150.000000   740.000000  13.900000
# 75%    44.750000   73000.000000  225.000000  1225.000000  15.700000
# max    60.000000  150000.000000  500.000000  4200.000000  45.000000

# %%
df.isnull().sum()
# Out:
# CustomerID    0
# Country       0
# Gender        1
# Age           1
# Salary        1
# Purchased     0
# Category      0
# Value         0
# Region        0
# Sales         0
# Feature       0
# Date          1
# dtype: int64

# %%
df['Category'].unique()
# Out:
# <StringArray>
# ['Electronics', 'Groceries', 'Fashion']
# Length: 3, dtype: str

# %%
df['Salary'].hist()
# Out:
# <Axes: >

# %%
sns.histplot(
    data=df,
    x="Age",
    bins=10,
    binwidth=5
)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(
    data=df,
    x="Salary",
    bins=7,
    binwidth=10000
)
# Out:
# <Axes: xlabel='Salary', ylabel='Count'>

# %%
df.boxplot(column='Age')
# Out:
# <Axes: >

# %%
df['Region'].describe()
# Out:
# count       35
# unique       4
# top       West
# freq        15
# Name: Region, dtype: object

# %%
sns.heatmap(df.corr(numeric_only=True), annot= True)
# Out:
# <Axes: >

# %%
numeric_df = df.select_dtypes(include='number')
sns.heatmap(numeric_df.corr(), annot=True)
plt.show()

# %%
df.groupby('Region')['Sales'].sum()
# Out:
# Region
# East      3580
# North     6200
# South     6610
# West     17150
# Name: Sales, dtype: int64

# %%
df.groupby('Region')['Sales'].mean()
# Out:
# Region
# East      716.000000
# North    1033.333333
# South     734.444444
# West     1143.333333
# Name: Sales, dtype: float64

# %%
df["Age"].fillna(df["Age"].mode()[0], inplace=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_33828\3959885965.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["Age"].fillna(df["Age"].mode()[0], inplace=True)
# 0     44.0
# 1     27.0
# 2     30.0
# 3     38.0
# 4     40.0
# 5     35.0
# 6     29.0
# 7     48.0
# 8     50.0
# 9     37.0
# 10    29.0
# 11    33.0
# 12    41.0
# 13    36.0
# 14    45.0
# 15    31.0
# 16    28.0
# 17    52.0
# 18    34.0
# 19    39.0
# 20    43.0
# 21    26.0
# 22    32.0
# 23    47.0
# 24    42.0
# 25    38.0
# 26    31.0
# 27    46.0
# 28    29.0
# 29    54.0
# 30    48.0
# 31    60.0
# 32    22.0
# 33    43.0
# 34    41.0
# Name: Age, dtype: float64

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34     True
# dtype: bool

# %%
df.drop_duplicates(subset= "Age")
# Out:
#    CustomerID       Country  Gender   Age    Salary Purchased     Category  \
# 0        C001        France  Female  44.0   72000.0        No  Electronics
# 1        C002         Spain    Male  27.0   48000.0       Yes    Groceries
# 2        C003       Germany  Female  30.0   54000.0        No  Electronics
# 3        C004         Spain     NaN  38.0   61000.0        No      Fashion
# 4        C005       Germany    Male  40.0       NaN       Yes    Groceries
# 5        C006        France  Female  35.0   58000.0       Yes      Fashion
# 6        C007         Spain    Male   NaN   52000.0        No  Electronics
# 7        C008        France  Female  48.0   79000.0       Yes  Electronics
# 8        C009       Germany    Male  50.0   83000.0        No      Fashion
# 9        C010        France  Female  37.0   67000.0       Yes    Groceries
# 10       C011       Nigeria    Male  29.0   45000.0        No  Electronics
# 11       C012       Nigeria  Female  33.0   51000.0       Yes    Groceries
# 12       C013         Kenya  Female  41.0   62000.0        No      Fashion
# 13       C014         Kenya    Male  36.0   59000.0       Yes  Electronics
# 14       C015  South Africa  Female  45.0   71000.0       Yes  Electronics
# 15       C016  South Africa    Male  31.0   53000.0        No    Groceries
# 16       C017         Ghana  Female  28.0   47000.0       Yes      Fashion
# 17       C018         Ghana    Male  52.0   86000.0        No  Electronics
# 18       C019        France  Female  34.0   60000.0       Yes    Groceries
# 19       C020         Spain    Male  39.0   65000.0        No      Fashion
# 20       C021       Germany  Female  43.0   73000.0       Yes  Electronics
# 21       C022       Nigeria    Male  26.0   42000.0        No    Groceries
# 22       C023         Kenya  Female  32.0   56000.0       Yes      Fashion
# 23       C024         Ghana    Male  47.0   78000.0        No  Electronics
# 24       C025  South Africa  Female  42.0   69000.0       Yes    Groceries
# 27       C028       Germany    Male  46.0   76000.0        No  Electronics
# 29       C030  South Africa    Male  54.0   90000.0        No      Fashion
# 31       C032       Nigeria    Male  60.0  150000.0       Yes  Electronics
# 32       C033         Spain  Female  22.0   35000.0        No    Groceries
#
#     Value Region  Sales  Feature        Date
# 0     220   West   1200     15.2  2025-01-03
# 1      85  South    540     11.4  2025-01-04
# 2     160  North    800     12.1  2025-01-05
# 3     140  South    670     14.8  2025-01-06
# 4      95  North    450     13.0  2025-01-07
# 5     130   West    610     12.7  2025-01-08
# 6     175  South    900     11.9  2025-01-09
# 7     260   West   1500     16.1  2025-01-10
# 8     205  North   1100     17.4  2025-01-11
# 9     115   West    580     13.6  2025-01-12
# 10    155   West    760     10.8  2025-01-13
# 11     98   West    500     12.3  2025-01-14
# 12    150   East    740     13.9  2025-01-15
# 13    210   East    980     14.1  2025-01-16
# 14    240  South   1300     15.5  2025-01-17
# 15     90  South    470     11.2  2025-01-18
# 16    125   West    620     12.5  2025-01-19
# 17    275   West   1600     18.2  2025-01-20
# 18    105   West    550     13.1  2025-01-21
# 19    145  South    690     14.0  2025-01-22
# 20    230  North   1250     15.7  2025-01-23
# 21     80   West    430     10.5  2025-01-24
# 22    138   East    660     12.9  2025-01-25
# 23    255   West   1480     16.4  2025-01-26
# 24    110  South    590     13.3  2025-01-27
# 27    245  North   1350     16.0  2025-01-30
# 29    215  South   1150     17.8  2025-02-01
# 31    500   West   4200     45.0  2025-02-03
# 32     60  South    300      9.8         NaN

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
df['Date'].head()
# Out:
# 0   2025-01-03
# 1   2025-01-04
# 2   2025-01-05
# 3   2025-01-06
# 4   2025-01-07
# Name: Date, dtype: datetime64[us]

# %%
df = pd.read_csv("eda_practice_dataset.csv")
df.head()
# Out:
#   CustomerID  Country  Gender   Age   Salary Purchased     Category  Value  \
# 0       C001   France  Female  44.0  72000.0        No  Electronics    220
# 1       C002    Spain    Male  27.0  48000.0       Yes    Groceries     85
# 2       C003  Germany  Female  30.0  54000.0        No  Electronics    160
# 3       C004    Spain     NaN  38.0  61000.0        No      Fashion    140
# 4       C005  Germany    Male  40.0      NaN       Yes    Groceries     95
#
#   Region  Sales  Feature        Date
# 0   West   1200     15.2  2025-01-03
# 1  South    540     11.4  2025-01-04
# 2  North    800     12.1  2025-01-05
# 3  South    670     14.8  2025-01-06
# 4  North    450     13.0  2025-01-07

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  35 non-null     str
#  1   Country     35 non-null     str
#  2   Gender      34 non-null     str
#  3   Age         34 non-null     float64
#  4   Salary      34 non-null     float64
#  5   Purchased   35 non-null     str
#  6   Category    35 non-null     str
#  7   Value       35 non-null     int64
#  8   Region      35 non-null     str
#  9   Sales       35 non-null     int64
#  10  Feature     35 non-null     float64
#  11  Date        34 non-null     str
# dtypes: float64(3), int64(2), str(7)
# memory usage: 3.4 KB

# %%
sales_by_region = df.groupby('Region')['Sales'].sum()

# %%
sales_by_region.plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: >

# %%
df['Salary'].plot()
# Out:
# <Axes: >

# %%
df['Region'].unique()
# Out:
# <StringArray>
# ['West', 'South', 'North', 'East']
# Length: 4, dtype: str

# %%
sns.scatterplot(x='Age', y= 'Salary', df= eda_practice_dataset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 sns.scatterplot(x='Age', y= 'Salary', df= eda_practice_dataset)
#
# NameError: name 'eda_practice_dataset' is not defined
