# %%
import pandas as pd 
import numpy as np  
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("Oilwell.csv") 
df.head
# Out:
# <bound method NDFrame.head of            Date  Oil volume   Gas volume  Water volume   Volume of liquid   \
# 0      1/1/2013           49       13055             21                 70
# 1      1/2/2013           49       13055             21                 70
# 2      1/3/2013           49       13055             21                 70
# 3      1/4/2013           49       13055             21                 70
# 4      1/5/2013           44       11768             26                 70
# ...         ...          ...         ...            ...                ...
# 2934  1/14/2021            6        1593             15                 20
# 2935  1/15/2021            6        1593             15                 20
# 2936  1/16/2021            6        1583             14                 20
# 2937  1/17/2021            6        1573             14                 20
# 2938  1/18/2021            5        1418             13                 18
#
# ...

# %%
df.head(1000)
# Out:
#           Date  Oil volume   Gas volume  Water volume   Volume of liquid   \
# 0     1/1/2013           49       13055             21                 70
# 1     1/2/2013           49       13055             21                 70
# 2     1/3/2013           49       13055             21                 70
# 3     1/4/2013           49       13055             21                 70
# 4     1/5/2013           44       11768             26                 70
# ..         ...          ...         ...            ...                ...
# 995  9/24/2015           24        6480             64                 88
# 996  9/25/2015           23        6129             61                 83
# 997  9/26/2015           20        5385             53                 73
# 998  9/27/2015           21        5619             55                 76
# 999  9/28/2015           21        5619             55                 76
#
#      Water cut   Working hours   Dynamic levels   Reservoir pressure
# ...

# %%
df.shape
# Out:
# (2939, 9)

# %%
df.describe()
# Out:
#        Oil volume     Gas volume  Water volume   Volume of liquid   \
# count  2939.000000   2939.000000    2939.000000        2939.000000
# mean     17.624362   4730.146308      41.828853          59.464103
# std       9.689026   2598.888524      13.056625          18.634101
# min       0.000000      4.000000       9.000000          12.000000
# 25%      11.000000   3041.500000      33.000000          50.000000
# 50%      15.000000   3909.000000      43.000000          58.000000
# 75%      22.000000   5843.500000      50.000000          74.000000
# max      49.000000  13113.000000      99.000000         113.000000
#
#         Water cut   Working hours   Dynamic levels   Reservoir pressure
# count  2939.000000     2939.000000      2939.000000          2939.000000
# mean     70.694794       22.344675      1930.383464           157.019054
# std       9.534203        3.039553       114.543752            32.917150
# min      29.000000        7.000000      1529.000000           100.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2939 entries, 0 to 2938
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 2939 non-null   str
#  1   Oil volume           2939 non-null   int64
#  2   Gas volume           2939 non-null   int64
#  3   Water volume         2939 non-null   int64
#  4   Volume of liquid     2939 non-null   int64
#  5   Water cut            2939 non-null   int64
#  6   Working hours        2939 non-null   int64
#  7   Dynamic levels       2939 non-null   int64
#  8   Reservoir pressure   2939 non-null   int64
# dtypes: int64(8), str(1)
# memory usage: 206.8 KB

# %%
df.isnull().sum()
# Out:
# Date                   0
# Oil volume             0
# Gas volume             0
# Water volume           0
# Volume of liquid       0
# Water cut              0
# Working hours          0
# Dynamic levels         0
# Reservoir pressure     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Date', 'Oil volume ', 'Gas volume', 'Water volume ',
#        'Volume of liquid ', 'Water cut ', 'Working hours ', 'Dynamic levels ',
#        'Reservoir pressure '],
#       dtype='str')

# %%
df.iloc[:, 4].hist()
plt.show()

# %%
boxplot = sns.boxplot( y = df.iloc[:, -1], data = df)

# %%
boxplot = sns.boxplot( y = df.iloc[:, 1], data = df)

# %%
sns.boxplot( y= "Gas volume", data=df)
# Out:
# <Axes: ylabel='Gas volume'>

# %%
sns.boxplot( y= 'Oil volume ', data=df)
# Out:
# <Axes: ylabel='Oil volume '>

# %%
sns.scatterplot(data= df, y= 'Oil volume ',x= 'Reservoir pressure ' )
# Out:
# <Axes: xlabel='Reservoir pressure ', ylabel='Oil volume '>

# %%
sns.scatterplot(data= df, y= 'Oil volume ',x= 'Dynamic levels ' )
# Out:
# <Axes: xlabel='Dynamic levels ', ylabel='Oil volume '>

# %%
sns.scatterplot(data= df, y= 'Oil volume ',x= 'Water cut ' )
# Out:
# <Axes: xlabel='Water cut ', ylabel='Oil volume '>

# %%
sns.scatterplot(data= df, y= 'Oil volume ',x= 'Working hours ' )
# Out:
# <Axes: xlabel='Working hours ', ylabel='Oil volume '>

# %%
sns.scatterplot(data= df, y= 'Gas volume',x= 'Reservoir pressure ' )
# Out:
# <Axes: xlabel='Reservoir pressure ', ylabel='Gas volume'>

# %%
sns.scatterplot(data= df, y= 'Gas volume',x= 'Water cut ' )
# Out:
# <Axes: xlabel='Water cut ', ylabel='Gas volume'>

# %%
sns.scatterplot(data= df, y= 'Gas volume',x= 'Working hours ' )
# Out:
# <Axes: xlabel='Working hours ', ylabel='Gas volume'>

# %%
df.head(1000)
# Out:
#           Date  Oil volume   Gas volume  Water volume   Volume of liquid   \
# 0     1/1/2013           49       13055             21                 70
# 1     1/2/2013           49       13055             21                 70
# 2     1/3/2013           49       13055             21                 70
# 3     1/4/2013           49       13055             21                 70
# 4     1/5/2013           44       11768             26                 70
# ..         ...          ...         ...            ...                ...
# 995  9/24/2015           24        6480             64                 88
# 996  9/25/2015           23        6129             61                 83
# 997  9/26/2015           20        5385             53                 73
# 998  9/27/2015           21        5619             55                 76
# 999  9/28/2015           21        5619             55                 76
#
#      Water cut   Working hours   Dynamic levels   Reservoir pressure
# ...

# %%
y = df.iloc[:, 1]    
x = df.iloc[:, 5:]

# %%
print(y)
# Out:
# 0       49
# 1       49
# 2       49
# 3       49
# 4       44
#         ..
# 2934     6
# 2935     6
# 2936     6
# 2937     6
# 2938     5
# Name: Oil volume , Length: 2939, dtype: int64

# %%
print(x)
# Out:
#       Water cut   Working hours   Dynamic levels   Reservoir pressure
# 0             29              24             1819                  214
# 1             29              24             1836                  214
# 2             29              24             1788                  214
# 3             29              24             1789                  214
# 4             36              24             1825                  214
# ...          ...             ...              ...                  ...
# 2934          70              16             2101                  100
# 2935          70              16             2113                  100
# 2936          70              16             2125                  100
# 2937          70              16             2125                  100
# 2938          70              15             2125                  100
#
# [2939 rows x 4 columns]

# %%
corr = df.corr(numeric_only = True)
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
from sklearn.impute import SimpleImputer

# %%
from sklearn.model_selection import train_test_split    
x_train, x_test, y_train, y_test = train_test_split( 
    x,y, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler    
scaler = StandardScaler()   
x_train = scaler.fit_transform(x_train) 
x_test = scaler.fit_transform(x_test)

# %% [markdown]
# TRAIN LINEAR REGRESSION MODEL

# %%
from sklearn.linear_model import LinearRegression   
model = LinearRegression()  
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print(y_test)
# Out:
# 2312    13
# 650     29
# 2602     9
# 177     37
# 1340    13
#         ..
# 859     24
# 1406    14
# 962     28
# 2659     9
# 2273    13
# Name: Oil volume , Length: 588, dtype: int64

# %%
print(y_train)
# Out:
# 456     32
# 462     26
# 2216    16
# 2668     9
# 381     24
#         ..
# 1638    15
# 1095    13
# 1130    16
# 1294    13
# 860     20
# Name: Oil volume , Length: 2351, dtype: int64

# %%
print(x_test)
# Out:
# [[ 0.59148416  0.557658    1.64405364 -1.00359298]
#  [-0.8388559   0.557658   -0.16605516  0.93012973]
#  [ 0.481458   -1.68605688  1.74949687 -1.33083836]
#  ...
#  [-0.39875127  0.557658   -0.78992761  0.57313477]
#  [ 0.26140569 -2.00658758  1.74949687 -1.39033752]
#  [ 0.81153648  0.557658    1.53861041 -0.94409382]]

# %%
print(x_train)
# Out:
# [[-0.59255996  0.54146183 -1.87707213  1.19641427]
#  [-0.07390454  0.54146183 -0.68239769  1.19641427]
#  [ 0.44475088  0.54146183  0.89596781 -0.88112178]
#  ...
#  [ 0.65221305  0.54146183 -0.58647492  0.40206225]
#  [ 0.54848197  0.54146183 -0.31614713  0.21875025]
#  [-0.90375321 -1.77786074  0.11114519  0.73813426]]

# %% [markdown]
# MAKE PREDICTION

# %%
y_pred = model.predict(x_test)

# %% [markdown]
# EVALUATE MODEL

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test, y_pred)
# Out:
# 1.5239148225595454

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, y_pred)
# Out:
# 3.9860314055494794

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.9576017181514584
