# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Agboolar Energy Limited.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of      well_id    field  depth_m  pressure_psi  temperature_c  porosity  \
# 0          1  Field_C   4594.0        4098.0          119.8     0.323
# 1          2  Field_A   3042.0        4701.0          122.3     0.189
# 2          3  Field_C   3486.0        3398.0          137.4     0.091
# 3          4  Field_C   3772.0        3944.0           84.1     0.152
# 4          5  Field_A   3172.0        2096.0          146.2     0.099
# ..       ...      ...      ...           ...            ...       ...
# 495      496  Field_B   2505.0        4196.0          118.3     0.334
# 496      497  Field_B   3074.0        3303.0          109.7     0.151
# 497      498  Field_A   2889.0        2270.0          120.6     0.267
# 498      499  Field_B   3412.0        2300.0          109.6     0.212
# 499      500  Field_C   2938.0        2436.0          124.8     0.068
#
#      permeability_mD  water_cut  gas_oil_ratio  production_bpd well_status
# ...

# %%
df.describe()
# Out:
#           well_id      depth_m  pressure_psi  temperature_c    porosity  \
# count  500.000000   500.000000    500.000000     500.000000  475.000000
# mean   250.500000  3017.758000   3590.284000     119.707000    0.202611
# std    144.481833   536.090389    856.154713      19.017517    0.086449
# min      1.000000  1318.000000   1412.000000      53.000000    0.051000
# 25%    125.750000  2649.000000   3010.500000     106.450000    0.128000
# 50%    250.500000  3028.000000   3559.500000     120.550000    0.209000
# 75%    375.250000  3408.500000   4165.500000     132.425000    0.276000
# max    500.000000  4594.000000   6034.000000     174.000000    0.350000
#
#        permeability_mD   water_cut  gas_oil_ratio  production_bpd
# count       475.000000  475.000000     500.000000      500.000000
# mean        150.836000    0.525080     790.448200     1489.346000
# std         149.868498    0.279903     192.855723      405.309756
# ...

# %%
df.isnull().sum()
# Out:
# well_id             0
# field               0
# depth_m             0
# pressure_psi        0
# temperature_c       0
# porosity           25
# permeability_mD    25
# water_cut          25
# gas_oil_ratio       0
# production_bpd      0
# well_status         0
# dtype: int64

# %%
df.columns
# Out:
# Index(['well_id', 'field', 'depth_m', 'pressure_psi', 'temperature_c',
#        'porosity', 'permeability_mD', 'water_cut', 'gas_oil_ratio',
#        'production_bpd', 'well_status'],
#       dtype='str')

# %%
df['production_bpd'].hist()
# Out:
# <Axes: >

# %%
sns.histplot(
    data=df,
    x="production_bpd",
    bins=10,
    binwidth=50
)
# Out:
# <Axes: xlabel='production_bpd', ylabel='Count'>
