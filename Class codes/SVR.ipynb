# %%
import numpy as np  
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split 
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.svm import SVR

# %%
df = pd.read_csv("Oilwell.csv")
x = df.iloc[:, [5,8]].values
y = df.iloc[:, 1].values.reshape(-1,1)

# %%
print(x)
print(y)
# Out:
# [[ 29 214]
#  [ 29 214]
#  [ 29 214]
#  ...
#  [ 70 100]
#  [ 70 100]
#  [ 70 100]]
# [[49]
#  [49]
#  [49]
#  ...
#  [ 6]
#  [ 6]
#  [ 5]]

# %%
#Split into training test set 
x_train, x_test, y_train, y_test = train_test_split (x, y, test_size = 0.2, random_state = 42 )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #Split into training test set
# ----> 2 x_train, x_test, y_train, y_test = train_test_split (x, y, test_size = 0.2, random_state = 42 )
#
# NameError: name 'train_test_split' is not defined

# %%
# Feature scaling (required for SVR)
sc_X = StandardScaler()
sc_y = StandardScaler()

X_train_sc = sc_X.fit_transform(X_train)
X_test_sc  = sc_X.transform(X_test)
y_train_sc = sc_y.fit_transform(y_train).ravel()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 5
#       1 # Feature scaling (required for SVR)
#       2 sc_X = StandardScaler()
#       3 sc_y = StandardScaler()
#       4
# ----> 5 X_train_sc = sc_X.fit_transform(X_train)
#       6 X_test_sc  = sc_X.transform(X_test)
#       7 y_train_sc = sc_y.fit_transform(y_train).ravel()
#       8
#
# NameError: name 'X_train' is not defined

# %%
#Train model
regressor = SVR(kernel = 'rbf', C=100, gamma =0.1, epsilon =0.1)
regressor.fit(x_train_sc, y_train_sc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 3
#       1 #Train model
#       2 regressor = SVR(kernel = 'rbf', C=100, gamma =0.1, epsilon =0.1)
# ----> 3 regressor.fit(x_train_sc, y_train_sc)
#
# NameError: name 'x_train_sc' is not defined

# %%
#Predict and inverse-transform
y_pred_sc = regressor.predict(x_test_sc)
y_pred = sc_y.inverse_transform(y_pred_sc.reshape(-1, 1)).ravel()
y_test = y_test.ravel()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 #Predict and inverse-transform
# ----> 2 y_pred_sc = regressor.predict(x_test_sc)
#       3 y_pred = sc_y.inverse_transform(y_pred_sc.reshape(-1, 1)).ravel()
#       4 y_test = y_test.ravel()
#
# NameError: name 'x_test_sc' is not defined

# %%
#EVALUATE
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f"kernel : rbf")
print(f"C : 100 | Gamma: 0.1 | Epsilon:0.1")
print(f"MSE : {mse:.4f}")
print(f"RMSE : {rmse:.4f}")
print(f"R2 score : {r2:.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 #EVALUATE
# ----> 2 mse = mean_squared_error(y_test, y_pred)
#       3 rmse = np.sqrt(mse)
#       4 r2 = r2_score(y_test, y_pred)
#       5
#
# NameError: name 'mean_squared_error' is not defined

# %%
Plot Actual Vs Predicted 
plt.figure(figsize=(8,5))
plt.scatter(y_test, y_pred, color= 'red', alpha=0.7)
plt.plot([y_test.min(), y_test.max()], [y_test.min(),y_test.max], 'b--', lw)
plt.xlabel("Actual value") 
plt.ylabel("Predicted value") 
plt.title("SVR-Actual VS Predicted")
plt.tight_layout()
plt.savefig("svr_plot.png", dpi =150)
plt.show()
# Out:
#   Cell In[20], line 1
#     Plot Actual Vs Predicted
#          ^
# SyntaxError: invalid syntax
